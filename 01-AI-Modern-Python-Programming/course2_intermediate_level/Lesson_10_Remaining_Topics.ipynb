# %% [markdown]
# # 📚 Missing Topics Covered in This Notebook
#
# This notebook includes the following topics:
#
# - Binary Types (`bytes`, `bytearray`, `memoryview`)
# - `isinstance()` Function
# - Chained Comparison Operators
# - Deleting a Variable using the `del` Keyword
# - `%` Operator for String Formatting
# - `str.format()` Method
# - String Repetition
# - Higher-order functions
# - Generators in python
#
# ---

# %% [markdown]
# ## 🗂️ Binary Types in Python
#
# Python provides special data types for working with **raw bytes and binary data**. These are essential for tasks like reading files, handling images/audio, or sending data over a network.
#
# **Main Binary Types:**
# - `bytes` (immutable)
# - `bytearray` (mutable)
# - `memoryview` (efficient views/slices)

# %% [markdown]
# ### 1. `bytes`
#
# Think of bytes as a read-only string of numbers between 0 and 255. Once you create it, you can’t change it.
#
# - **Immutable** sequence of bytes (0-255)
# - Used for storing binary data (e.g., file contents, network messages)
# - Created with `b"..."` or `bytes()`

# %%
# Creating a bytes object
byte_data = b"Hello"
print(type(byte_data), byte_data)

# Each character represents a byte (ASCII value)
print(list(byte_data))  # Shows the integer values
# Out:
# <class 'bytes'> b'Hello'
# [72, 101, 108, 108, 111]

# %% [markdown]
# **Key Points:**
# - Immutable: cannot change after creation
# - Often used for reading files in binary mode:
#   ```python
#   with open('file.jpg', 'rb') as f:
#       data = f.read()
#   ```

# %% [markdown]
# ### 2. `bytearray`
# Same concept as bytes, but you can modify it after creation. It behaves like a list of bytes.
#
# - Like `bytes`, but **mutable** (can change contents)
# - Useful for modifying binary data in-place
# - Created with `bytearray()`

# %%
# Creating a bytearray object
byte_arr = bytearray(b"hello")
print(type(byte_arr), byte_arr)
print(list(byte_arr))

print("-"*40)

# Change 'h' to 'H' (ASCII 72)
byte_arr[0] = 72
print(byte_arr)
print(list(byte_arr))  # Output: b'Hello'
print(byte_arr.decode())
# Out:
# <class 'bytearray'> bytearray(b'hello')
# [104, 101, 108, 108, 111]
# ----------------------------------------
# bytearray(b'Hello')
# [72, 101, 108, 108, 111]
# Hello

# %% [markdown]
# **Key Points:**
# - Mutable: can change, add, or remove bytes
# - Easy conversion:
#   - `bytes(byte_arr)`
#   - `bytearray(byte_data)`

# %% [markdown]
# ### 3. `memoryview`
# This one's about efficiency. `memoryview` lets you peek into a `bytes` or `bytearray` without copying it. That's a big deal for large files or network streams.
#
# - Provides a view of another binary object (like `bytes` or `bytearray`) **without copying data**
# - Efficient for slicing/processing large data buffers

# %%
data = b"BinaryData"                    # Create a bytes object (binary data)
mv = memoryview(data)                   # Create a memoryview of the bytes (no copy)

print(type(mv), mv)                     # Show the type and memoryview object

# Access a slice of the memoryview without copying the data
chunk = mv[0:6]                        # Slice the first 6 bytes (b'Binary')

print(chunk.tobytes())                  # Convert the slice back to bytes and print
print(chunk.tobytes().decode())        # Decode bytes to string and print ('Binary')

# Example of encoding a string to bytes
# newbyte = "Hello".encode()
# print(type(newbyte), newbyte)
# Out:
# <class 'memoryview'> <memory at 0x00000250B3242800>
# b'Binary'
# Binary

# %% [markdown]
# Even though it feels like slicing a list, it's not copying the data. Just referencing it.
#
# ---
#
# **🧠 Real Benefit**
# You avoid duplication. Imagine working with a 2 GB file — memoryview lets you extract and work with chunks without duplicating those chunks in memory.

# %%
# Original mutable bytearray
data = bytearray(b'hello world')

# Create a memoryview of the bytearray
mv = memoryview(data)

# Print original data
print("Before modification:", data)

# Modify the 0th and 6th byte via memoryview
mv[0] = ord('H')      # 'h' -> 'H'
mv[6] = ord('W')      # 'w' -> 'W'

# Print modified data
print("After modification: ", data)

# Show that no copy was made — it's the same memory
print("Memoryview slice:   ", mv[:5].tobytes())  # b'Hello'
# Out:
# Before modification: bytearray(b'hello world')
# After modification:  bytearray(b'Hello World')
# Memoryview slice:    b'Hello'

# %% [markdown]
# **Key Points:**
# - No data copy: memory-efficient
# - Useful for working with parts of big files/buffers

# %% [markdown]
# ### 🔑 Summary Table
#
# | Type         | Mutable? | Example                    | Use Case                               |
# |--------------|----------|----------------------------|----------------------------------------|
# | `bytes`      | No       | `b"hello"`                | Read-only binary data                  |
# | `bytearray`  | Yes      | `bytearray(b"hello")`     | Modifiable binary data                 |
# | `memoryview` | N/A      | `memoryview(b"data")`     | Efficient data slicing/views           |

# %% [markdown]
# > **Why learn binary types?**
# - To work with images, audio, or any non-text files
# - For networking/protocols needing raw bytes
# - To use less memory by avoiding unnecessary copies

# %% [markdown]
# ---
#
# ## **isinstance() Function in Python**
#
# The `isinstance()` function in Python is used to check if an object (first argument) is an instance of a class (second argument). It returns `True` if the object is an instance of the class, and `False` otherwise.
#
# ### **Syntax**
#
# ```python
# isinstance(object, classinfo)
# ```
# Where:
#
# * `object` is the object to be checked.
# * `classinfo` is the class or a tuple of classes to check against.

# %%
age: int = 20
weight: float = 66.89
print("check: isinstance(age, int)      = ", isinstance(age, int))
print("check: isinstance(weight, int)   = ", isinstance(weight, int))
print("check: isinstance(weight, float) = ", isinstance(weight, float))
# Out:
# check: isinstance(age, int)      =  True
# check: isinstance(weight, int)   =  False
# check: isinstance(weight, float) =  True

# %% [markdown]
# ---
#
# ## **String Formatting in Python**
#
# Python provides several ways to format strings:

# %% [markdown]
# ### 1. `%` Operator (Old Style)
#
# ```python
# my_string = 'Hello, %s!' % 'World'
# ```
# - Placeholders: `%s` (string), `%d` (int), `%c` (char), `%f` (float), `%.nf` (float with n decimals)
# - **Note:** `%` formatting is older; prefer `str.format()` or f-strings in new code.

# %% [markdown]
# ### 2. `str.format()` (New Style)
#
# ```python
# my_string = 'Hello, {}!'.format('World')
# ```
# - Use `{}` as placeholders, values are inserted in order or by index.

# %% [markdown]
# ### 3. f-Strings (Python 3.6+)
#
# ```python
# name = 'World'
# my_string = f'Hello, {name}!'
# ```
# - Most modern and readable way to format strings.

# %% [markdown]
# #### Common Placeholders (for `%` formatting)
#
# | Placeholder | Meaning                              | Example                                |
# |-------------|--------------------------------------|----------------------------------------|
# | %s          | String                               | "Hello, %s" % "Alice" → "Hello, Alice" |
# | %d          | Integer (Decimal)                    | "Age: %d" % 25 → "Age: 25"             |
# | %c          | Character                            | "Letter: %c" % 'A' → "Letter: A"       |
# | %f          | Floating-point                       | "Pi: %f" % 3.14159 → "Pi: 3.141590"    |
# | %.nf        | Floating-point with n decimal places | "%.2f" % 3.14159 → "3.14"              |

# %% [markdown]
# ### `%` Operator Example

# %%
name = 'John'
age = 20
first_letter = name[0]
my_weight = 70.532

# Using % operator
my_string = """My name is %s, first letter of my name is '%c', I am %d years old and my weight is %f Kg.""" % (name, first_letter, age, my_weight)
print(my_string)

# With 2 decimal places
my_string = """My name is %s, first letter of my name is '%c', I am %d years old and my weight is %.2f Kg.""" % (name, first_letter, age, my_weight)
print(my_string)
# Out:
# My name is John, first letter of my name is 'J', I am 20 years old and my weight is 70.532000 Kg.
# My name is John, first letter of my name is 'J', I am 20 years old and my weight is 70.53 Kg.

# %% [markdown]
# > **Order matters!**
# - The order of values must match the order of placeholders.
# - Wrong order or wrong types will cause errors.

# %%
# Example of incorrect order (will raise TypeError)
# my_string = "My name is %s, first letter of my name is '%c', I am %d years old and my weight is %f Kg." % (my_weight, age, name, first_letter)

# %% [markdown]
# ### `str.format()` Example

# %%
# Using str.format()
my_string = 'My name is {} and I am {} years old.'.format('Alice', 25)
print("Line 1:", my_string)

# Using indexes
my_string = 'My name is {1} and I am {0} years old.'.format(25, 'Alice')
print("Line 2:", my_string)
# Out:
# Line 1: My name is Alice and I am 25 years old.
# Line 2: My name is Alice and I am 25 years old.

# %% [markdown]
# ---
#
# ## **String Repetition in Python**
#
# You can repeat strings using the `*` operator:

# %% [markdown]
# - Multiply a string by an integer to repeat it.
# - Example: `'abc' * 3` → `'abcabcabc'`
# - Multiplying by zero gives an empty string.
# - Useful for visual separators, patterns, or repeated elements.

# %%
# String repetition examples
base_string = "Hello"
repetition_count = 3
repeated_string = base_string * repetition_count
print(f"Original string: {base_string}")
print(f"Repeated string: {repeated_string}")

# Visual separator
separator = "-" * 30
print(separator)

# Pattern repetition
pattern = "* "
repeated_pattern = pattern * 5
print(repeated_pattern)

# Repeating zero times
empty_string = "Test" * 0
print(f"Empty string: '{empty_string}'")

# Using repetition in a loop
for i in range(1, 6):
    print("*" * i)
# Out:
# Original string: Hello
# Repeated string: HelloHelloHello
# ------------------------------
# * * * * *
# Empty string: ''
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ---

# %% [markdown]
# **Extra(Optional):**
#
# 🖼️ Displaying an Image Using Raw Bytes in Python

# %%
# from IPython.display import display
# from PIL import Image
# import io

# # Read image bytes
# with open("my-pic-pro.png", "rb") as f:
#     image_bytes = f.read()

# # Convert bytes to a PIL image and display
# image = Image.open(io.BytesIO(image_bytes))
# display(image)

# %% [markdown]
# ## Higher-Order Functions (HOF)
#
# <!-- <hr color=grey> -->
#
#
# **A higher-order function is any function that either:**
# - Takes another function as an argument
# - Returns a function
#
#
# **Example 1:** Passing a function as an argument

# %%
def shout(text):
    print(text.upper())

def greet(func):
  def wrapper():
    func("hello")
  return wrapper

greet(shout)()
# Out:
# HELLO

# %% [markdown]
# **Example 2:** Returning a function

# %%
def outer():
    def inner():
        return "Inner function"
    return inner

print("Example 2:")
fn = outer()
print(fn())  # Output: Inner function

# Built-in functions that use HOFs: map, filter, sorted
nums = [1, 2, 3, 4]
squares = list(map(lambda x: x**2, nums))
print("Example 3:", squares)  # Output: [1, 4, 9, 16]
# Out:
# Example 2:
# Inner function
# Example 3: [1, 4, 9, 16]

# %% [markdown]
# ## **Generator Function**
#
# A generator function in Python is a special type of function that allows you to iterate over a sequence of values `without storing the entire sequence in memory`. **Instead of returning a single value using return, a generator function uses the `yield` keyword to produce a series of values, `one at a time`, `on-the-fly`**. This makes generator functions highly `memory-efficient` for working with `large` or `infinite sequences`.
#
#
# ## **Key Features of Generator Functions**
#
# 1. **Lazy Evaluation**: Values are generated only when needed, not all at once.
#
# 2.  **Memory Efficiency**: Only one value is stored in memory at a time.
# 3.  **Iterable**: Generator functions return a generator object, which can be iterated over using a for loop or functions like next().
# 4.  **Resumable**: The state of the generator function is saved between yield calls, allowing it to resume execution from where it left off.
#
#
# ## **Syntax of a Generator Function**
#
# A generator function is defined like a normal function but uses the `yield` keyword instead of return.
#
# ```python
# def generator_function():
#     yield value
#
# ```
#
#
# ## **How Generator Functions Work**
#
# 1.  When a generator function is called, it returns a generator object without executing the function body.
#
# 2.  The function body executes only when the generator object is iterated over (e.g., using a for loop or next()).
# 3.  When the yield statement is encountered, the function pauses and returns the yielded value. The function’s state (e.g., local variables) is saved.
# 4.  The function resumes execution from where it left off the next time next() is called or the generator is iterated over.
#
#
# ### **Example 1:** Simple Generator Function

# %%
def simple_generator():
    yield 1
    yield 2
    yield 3

# Create a generator object
gen = simple_generator()

print(gen, " : ", type(gen))

# print(next(gen))
# print(next(gen))
# print(next(gen))
# print(next(gen)) # StopIteration Error



# # Iterate over the generator

for value in gen:
  print(value)


# for value in gen:
#   if value == 2:
#     print(value)


# dir(gen)
# Out:
# <generator object simple_generator at 0x7d57a1eee560>  :  <class 'generator'>
# 1
# 2
# 3
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'close',
#  'gi_code',
#  'gi_frame',
#  'gi_running',
#  'gi_suspended',
#  'gi_yieldfrom',
#  'send',
#  'throw']

# %% [markdown]
# ### **Lets produce an error:**
#
# **Once the generator is exhausted, calling next() will raise a StopIteration exception.**

# %%
print(next(gen)) #error: StopIteration
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-791576904.py in <cell line: 0>()
# ----> 1 print(next(gen)) #error: StopIteration
#
# StopIteration:

# %% [markdown]
# ### **Example 2: Infinite Sequence**
#
# Generators are useful for generating infinite sequences since they don’t store all values in memory.
#
# ### **How It Works:**
#
# 1.  infinite_sequence():
#     * This function starts with num = 0.
#
#     * Inside an infinite while True loop, it yields num and then increments it by 1.
#     * Since yield pauses execution, it remembers the state and resumes from there when next() is called.
#
# 2.  Creating the Generator:
#
#     * gen = infinite_sequence() initializes the generator.
#
#
# 3.  Printing First 5 Numbers:
#
#     * Using next(gen), we retrieve values from the generator five times inside a loop.
#
#     * The next time we call next(gen), execution resumes from where it left off.

# %%
def infinite_sequence():
    num = 0
    while True:
        num += 1
        yield num # Since yield pauses execution, it remembers the state and resumes from there when next() is called.

# Create a generator object
gen = infinite_sequence() #initializes the generator.

# print(next(gen))
# print(next(gen))

# for value in range(5):
#     print(value)

# Print the first 5 numbers, _ is a throw away variable
for _ in range(6):
    print(next(gen)) # The next time we call next(gen), execution resumes from where it left off.


next(gen)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# #### Note: without yield it become infinite

# %%
def infinite_loop(): #without yield it become infinite
   num = 0
   while True:
       #yield num   # with yield it become generator without yield its a infinite loop
       num += 1
       print("infinite_loop() : num = ", num)

infinite_loop()
# Out:
# Streaming output truncated to the last 5000 lines.
# infinite_loop() : num =  3566511
# infinite_loop() : num =  3566512
# infinite_loop() : num =  3566513
# infinite_loop() : num =  3566514
# infinite_loop() : num =  3566515
# infinite_loop() : num =  3566516
# infinite_loop() : num =  3566517
# infinite_loop() : num =  3566518
# infinite_loop() : num =  3566519
# infinite_loop() : num =  3566520
# infinite_loop() : num =  3566521
# infinite_loop() : num =  3566522
# infinite_loop() : num =  3566523
# infinite_loop() : num =  3566524
# infinite_loop() : num =  3566525
# infinite_loop() : num =  3566526
# infinite_loop() : num =  3566527
# infinite_loop() : num =  3566528
# infinite_loop() : num =  3566529
# infinite_loop() : num =  3566530
# infinite_loop() : num =  3566531
# infinite_loop() : num =  3566532
# infinite_loop() : num =  3566533
# infinite_loop() : num =  3566534
# infinite_loop() : num =  3566535
# infinite_loop() : num =  3566536
# infinite_loop() : num =  3566537
# infinite_loop() : num =  3566538
# infinite_loop() : num =  3566539
# infinite_loop() : num =  3566540
# infinite_loop() : num =  3566541
# infinite_loop() : num =  3566542
# infinite_loop() : num =  3566543
# infinite_loop() : num =  3566544
# infinite_loop() : num =  3566545
# infinite_loop() : num =  3566546
# infinite_loop() : num =  3566547
# infinite_loop() : num =  3566548
# infinite_loop() : num =  3566549
# infinite_loop() : num =  3566550
# infinite_loop() : num =  3566551
# infinite_loop() : num =  3566552
# infinite_loop() : num =  3566553
# infinite_loop() : num =  3566554
# infinite_loop() : num =  3566555
# infinite_loop() : num =  3566556
# infinite_loop() : num =  3566557
# infinite_loop() : num =  3566558
# infinite_loop() : num =  3566559
# infinite_loop() : num =  3566560
# infinite_loop() : num =  3566561
# infinite_loop() : num =  3566562
# infinite_loop() : num =  3566563
# infinite_loop() : num =  3566564
# infinite_loop() : num =  3566565
# infinite_loop() : num =  3566566
# infinite_loop() : num =  3566567
# infinite_loop() : num =  3566568
# infinite_loop() : num =  3566569
# infinite_loop() : num =  3566570
# infinite_loop() : num =  3566571
# infinite_loop() : num =  3566572
# infinite_loop() : num =  3566573
# infinite_loop() : num =  3566574
# infinite_loop() : num =  3566575
# infinite_loop() : num =  3566576
# infinite_loop() : num =  3566577
# infinite_loop() : num =  3566578
# infinite_loop() : num =  3566579
# infinite_loop() : num =  3566580
# infinite_loop() : num =  3566581
# infinite_loop() : num =  3566582
# infinite_loop() : num =  3566583
# infinite_loop() : num =  3566584
# infinite_loop() : num =  3566585
# infinite_loop() : num =  3566586
# infinite_loop() : num =  3566587
# infinite_loop() : num =  3566588
# infinite_loop() : num =  3566589
# infinite_loop() : num =  3566590
# infinite_loop() : num =  3566591
# infinite_loop() : num =  3566592
# infinite_loop() : num =  3566593
# infinite_loop() : num =  3566594
# infinite_loop() : num =  3566595
# infinite_loop() : num =  3566596
# infinite_loop() : num =  3566597
# infinite_loop() : num =  3566598
# infinite_loop() : num =  3566599
# infinite_loop() : num =  3566600
# infinite_loop() : num =  3566601
# infinite_loop() : num =  3566602
# infinite_loop() : num =  3566603
# infinite_loop() : num =  3566604
# infinite_loop() : num =  3566605
# infinite_loop() : num =  3566606
# infinite_loop() : num =  3566607
# infinite_loop() : num =  3566608
# infinite_loop() : num =  3566609
# infinite_loop() : num =  3566610
# infinite_loop() : num =  3566611
# infinite_loop() : num =  3566612
# infinite_loop() : num =  3566613
# infinite_loop() : num =  3566614
# infinite_loop() : num =  3566615
# infinite_loop() : num =  3566616
# infinite_loop() : num =  3566617
# infinite_loop() : num =  3566618
# infinite_loop() : num =  3566619
# infinite_loop() : num =  3566620
# infinite_loop() : num =  3566621
# infinite_loop() : num =  3566622
# infinite_loop() : num =  3566623
# infinite_loop() : num =  3566624
# infinite_loop() : num =  3566625
# infinite_loop() : num =  3566626
# infinite_loop() : num =  3566627
# infinite_loop() : num =  3566628
# infinite_loop() : num =  3566629
# infinite_loop() : num =  3566630
# infinite_loop() : num =  3566631
# infinite_loop() : num =  3566632
# infinite_loop() : num =  3566633
# infinite_loop() : num =  3566634
# infinite_loop() : num =  3566635
# infinite_loop() : num =  3566636
# infinite_loop() : num =  3566637
# infinite_loop() : num =  3566638
# infinite_loop() : num =  3566639
# infinite_loop() : num =  3566640
# infinite_loop() : num =  3566641
# infinite_loop() : num =  3566642
# infinite_loop() : num =  3566643
# infinite_loop() : num =  3566644
# infinite_loop() : num =  3566645
# infinite_loop() : num =  3566646
# infinite_loop() : num =  3566647
# infinite_loop() : num =  3566648
# infinite_loop() : num =  3566649
# infinite_loop() : num =  3566650
# infinite_loop() : num =  3566651
# infinite_loop() : num =  3566652
# infinite_loop() : num =  3566653
# infinite_loop() : num =  3566654
# infinite_loop() : num =  3566655
# infinite_loop() : num =  3566656
# infinite_loop() : num =  3566657
# infinite_loop() : num =  3566658
# infinite_loop() : num =  3566659
# infinite_loop() : num =  3566660
# infinite_loop() : num =  3566661
# infinite_loop() : num =  3566662
# infinite_loop() : num =  3566663
# infinite_loop() : num =  3566664
# infinite_loop() : num =  3566665
# infinite_loop() : num =  3566666
# infinite_loop() : num =  3566667
# infinite_loop() : num =  3566668
# infinite_loop() : num =  3566669
# infinite_loop() : num =  3566670
# infinite_loop() : num =  3566671
# infinite_loop() : num =  3566672
# infinite_loop() : num =  3566673
# infinite_loop() : num =  3566674
# infinite_loop() : num =  3566675
# infinite_loop() : num =  3566676
# infinite_loop() : num =  3566677
# infinite_loop() : num =  3566678
# infinite_loop() : num =  3566679
# infinite_loop() : num =  3566680
# infinite_loop() : num =  3566681
# infinite_loop() : num =  3566682
# infinite_loop() : num =  3566683
# infinite_loop() : num =  3566684
# infinite_loop() : num =  3566685
# infinite_loop() : num =  3566686
# infinite_loop() : num =  3566687
# infinite_loop() : num =  3566688
# infinite_loop() : num =  3566689
# infinite_loop() : num =  3566690
# infinite_loop() : num =  3566691
# infinite_loop() : num =  3566692
# infinite_loop() : num =  3566693
# infinite_loop() : num =  3566694
# infinite_loop() : num =  3566695
# infinite_loop() : num =  3566696
# infinite_loop() : num =  3566697
# infinite_loop() : num =  3566698
# infinite_loop() : num =  3566699
# infinite_loop() : num =  3566700
# infinite_loop() : num =  3566701
# infinite_loop() : num =  3566702
# infinite_loop() : num =  3566703
# infinite_loop() : num =  3566704
# infinite_loop() : num =  3566705
# infinite_loop() : num =  3566706
# infinite_loop() : num =  3566707
# infinite_loop() : num =  3566708
# infinite_loop() : num =  3566709
# infinite_loop() : num =  3566710
# infinite_loop() : num =  3566711
# infinite_loop() : num =  3566712
# infinite_loop() : num =  3566713
# infinite_loop() : num =  3566714
# infinite_loop() : num =  3566715
# infinite_loop() : num =  3566716
# infinite_loop() : num =  3566717
# infinite_loop() : num =  3566718
# infinite_loop() : num =  3566719
# infinite_loop() : num =  3566720
# infinite_loop() : num =  3566721
# infinite_loop() : num =  3566722
# infinite_loop() : num =  3566723
# infinite_loop() : num =  3566724
# infinite_loop() : num =  3566725
# infinite_loop() : num =  3566726
# infinite_loop() : num =  3566727
# infinite_loop() : num =  3566728
# infinite_loop() : num =  3566729
# infinite_loop() : num =  3566730
# infinite_loop() : num =  3566731
# infinite_loop() : num =  3566732
# infinite_loop() : num =  3566733
# infinite_loop() : num =  3566734
# infinite_loop() : num =  3566735
# infinite_loop() : num =  3566736
# infinite_loop() : num =  3566737
# infinite_loop() : num =  3566738
# infinite_loop() : num =  3566739
# infinite_loop() : num =  3566740
# infinite_loop() : num =  3566741
# infinite_loop() : num =  3566742
# infinite_loop() : num =  3566743
# infinite_loop() : num =  3566744
# infinite_loop() : num =  3566745
# infinite_loop() : num =  3566746
# infinite_loop() : num =  3566747
# infinite_loop() : num =  3566748
# infinite_loop() : num =  3566749
# infinite_loop() : num =  3566750
# infinite_loop() : num =  3566751
# infinite_loop() : num =  3566752
# infinite_loop() : num =  3566753
# infinite_loop() : num =  3566754
# infinite_loop() : num =  3566755
# infinite_loop() : num =  3566756
# infinite_loop() : num =  3566757
# infinite_loop() : num =  3566758
# infinite_loop() : num =  3566759
# infinite_loop() : num =  3566760
# infinite_loop() : num =  3566761
# infinite_loop() : num =  3566762
# infinite_loop() : num =  3566763
# infinite_loop() : num =  3566764
# infinite_loop() : num =  3566765
# infinite_loop() : num =  3566766
# infinite_loop() : num =  3566767
# infinite_loop() : num =  3566768
# infinite_loop() : num =  3566769
# infinite_loop() : num =  3566770
# infinite_loop() : num =  3566771
# infinite_loop() : num =  3566772
# infinite_loop() : num =  3566773
# infinite_loop() : num =  3566774
# infinite_loop() : num =  3566775
# infinite_loop() : num =  3566776
# infinite_loop() : num =  3566777
# infinite_loop() : num =  3566778
# infinite_loop() : num =  3566779
# infinite_loop() : num =  3566780
# infinite_loop() : num =  3566781
# infinite_loop() : num =  3566782
# infinite_loop() : num =  3566783
# infinite_loop() : num =  3566784
# infinite_loop() : num =  3566785
# infinite_loop() : num =  3566786
# infinite_loop() : num =  3566787
# infinite_loop() : num =  3566788
# infinite_loop() : num =  3566789
# infinite_loop() : num =  3566790
# infinite_loop() : num =  3566791
# infinite_loop() : num =  3566792
# infinite_loop() : num =  3566793
# infinite_loop() : num =  3566794
# infinite_loop() : num =  3566795
# infinite_loop() : num =  3566796
# infinite_loop() : num =  3566797
# infinite_loop() : num =  3566798
# infinite_loop() : num =  3566799
# infinite_loop() : num =  3566800
# infinite_loop() : num =  3566801
# infinite_loop() : num =  3566802
# infinite_loop() : num =  3566803
# infinite_loop() : num =  3566804
# infinite_loop() : num =  3566805
# infinite_loop() : num =  3566806
# infinite_loop() : num =  3566807
# infinite_loop() : num =  3566808
# infinite_loop() : num =  3566809
# infinite_loop() : num =  3566810
# infinite_loop() : num =  3566811
# infinite_loop() : num =  3566812
# infinite_loop() : num =  3566813
# infinite_loop() : num =  3566814
# infinite_loop() : num =  3566815
# infinite_loop() : num =  3566816
# infinite_loop() : num =  3566817
# infinite_loop() : num =  3566818
# infinite_loop() : num =  3566819
# infinite_loop() : num =  3566820
# infinite_loop() : num =  3566821
# infinite_loop() : num =  3566822
# infinite_loop() : num =  3566823
# infinite_loop() : num =  3566824
# infinite_loop() : num =  3566825
# infinite_loop() : num =  3566826
# infinite_loop() : num =  3566827
# infinite_loop() : num =  3566828
# infinite_loop() : num =  3566829
# infinite_loop() : num =  3566830
# infinite_loop() : num =  3566831
# infinite_loop() : num =  3566832
# infinite_loop() : num =  3566833
# infinite_loop() : num =  3566834
# infinite_loop() : num =  3566835
# infinite_loop() : num =  3566836
# infinite_loop() : num =  3566837
# infinite_loop() : num =  3566838
# infinite_loop() : num =  3566839
# infinite_loop() : num =  3566840
# infinite_loop() : num =  3566841
# infinite_loop() : num =  3566842
# infinite_loop() : num =  3566843
# infinite_loop() : num =  3566844
# infinite_loop() : num =  3566845
# infinite_loop() : num =  3566846
# infinite_loop() : num =  3566847
# infinite_loop() : num =  3566848
# infinite_loop() : num =  3566849
# infinite_loop() : num =  3566850
# infinite_loop() : num =  3566851
# infinite_loop() : num =  3566852
# infinite_loop() : num =  3566853
# infinite_loop() : num =  3566854
# infinite_loop() : num =  3566855
# infinite_loop() : num =  3566856
# infinite_loop() : num =  3566857
# infinite_loop() : num =  3566858
# infinite_loop() : num =  3566859
# infinite_loop() : num =  3566860
# infinite_loop() : num =  3566861
# infinite_loop() : num =  3566862
# infinite_loop() : num =  3566863
# infinite_loop() : num =  3566864
# infinite_loop() : num =  3566865
# infinite_loop() : num =  3566866
# infinite_loop() : num =  3566867
# infinite_loop() : num =  3566868
# infinite_loop() : num =  3566869
# infinite_loop() : num =  3566870
# infinite_loop() : num =  3566871
# infinite_loop() : num =  3566872
# infinite_loop() : num =  3566873
# infinite_loop() : num =  3566874
# infinite_loop() : num =  3566875
# infinite_loop() : num =  3566876
# infinite_loop() : num =  3566877
# infinite_loop() : num =  3566878
# infinite_loop() : num =  3566879
# infinite_loop() : num =  3566880
# infinite_loop() : num =  3566881
# infinite_loop() : num =  3566882
# infinite_loop() : num =  3566883
# infinite_loop() : num =  3566884
# infinite_loop() : num =  3566885
# infinite_loop() : num =  3566886
# infinite_loop() : num =  3566887
# infinite_loop() : num =  3566888
# infinite_loop() : num =  3566889
# infinite_loop() : num =  3566890
# infinite_loop() : num =  3566891
# infinite_loop() : num =  3566892
# infinite_loop() : num =  3566893
# infinite_loop() : num =  3566894
# infinite_loop() : num =  3566895
# infinite_loop() : num =  3566896
# infinite_loop() : num =  3566897
# infinite_loop() : num =  3566898
# infinite_loop() : num =  3566899
# infinite_loop() : num =  3566900
# infinite_loop() : num =  3566901
# infinite_loop() : num =  3566902
# infinite_loop() : num =  3566903
# infinite_loop() : num =  3566904
# infinite_loop() : num =  3566905
# infinite_loop() : num =  3566906
# infinite_loop() : num =  3566907
# infinite_loop() : num =  3566908
# infinite_loop() : num =  3566909
# infinite_loop() : num =  3566910
# infinite_loop() : num =  3566911
# infinite_loop() : num =  3566912
# infinite_loop() : num =  3566913
# infinite_loop() : num =  3566914
# infinite_loop() : num =  3566915
# infinite_loop() : num =  3566916
# infinite_loop() : num =  3566917
# infinite_loop() : num =  3566918
# infinite_loop() : num =  3566919
# infinite_loop() : num =  3566920
# infinite_loop() : num =  3566921
# infinite_loop() : num =  3566922
# infinite_loop() : num =  3566923
# infinite_loop() : num =  3566924
# infinite_loop() : num =  3566925
# infinite_loop() : num =  3566926
# infinite_loop() : num =  3566927
# infinite_loop() : num =  3566928
# infinite_loop() : num =  3566929
# infinite_loop() : num =  3566930
# infinite_loop() : num =  3566931
# infinite_loop() : num =  3566932
# infinite_loop() : num =  3566933
# infinite_loop() : num =  3566934
# infinite_loop() : num =  3566935
# infinite_loop() : num =  3566936
# infinite_loop() : num =  3566937
# infinite_loop() : num =  3566938
# infinite_loop() : num =  3566939
# infinite_loop() : num =  3566940
# infinite_loop() : num =  3566941
# infinite_loop() : num =  3566942
# infinite_loop() : num =  3566943
# infinite_loop() : num =  3566944
# infinite_loop() : num =  3566945
# infinite_loop() : num =  3566946
# infinite_loop() : num =  3566947
# infinite_loop() : num =  3566948
# infinite_loop() : num =  3566949
# infinite_loop() : num =  3566950
# infinite_loop() : num =  3566951
# infinite_loop() : num =  3566952
# infinite_loop() : num =  3566953
# infinite_loop() : num =  3566954
# infinite_loop() : num =  3566955
# infinite_loop() : num =  3566956
# infinite_loop() : num =  3566957
# infinite_loop() : num =  3566958
# infinite_loop() : num =  3566959
# infinite_loop() : num =  3566960
# infinite_loop() : num =  3566961
# infinite_loop() : num =  3566962
# infinite_loop() : num =  3566963
# infinite_loop() : num =  3566964
# infinite_loop() : num =  3566965
# infinite_loop() : num =  3566966
# infinite_loop() : num =  3566967
# infinite_loop() : num =  3566968
# infinite_loop() : num =  3566969
# infinite_loop() : num =  3566970
# infinite_loop() : num =  3566971
# infinite_loop() : num =  3566972
# infinite_loop() : num =  3566973
# infinite_loop() : num =  3566974
# infinite_loop() : num =  3566975
# infinite_loop() : num =  3566976
# infinite_loop() : num =  3566977
# infinite_loop() : num =  3566978
# infinite_loop() : num =  3566979
# infinite_loop() : num =  3566980
# infinite_loop() : num =  3566981
# infinite_loop() : num =  3566982
# infinite_loop() : num =  3566983
# infinite_loop() : num =  3566984
# infinite_loop() : num =  3566985
# infinite_loop() : num =  3566986
# infinite_loop() : num =  3566987
# infinite_loop() : num =  3566988
# infinite_loop() : num =  3566989
# infinite_loop() : num =  3566990
# infinite_loop() : num =  3566991
# infinite_loop() : num =  3566992
# infinite_loop() : num =  3566993
# infinite_loop() : num =  3566994
# infinite_loop() : num =  3566995
# infinite_loop() : num =  3566996
# infinite_loop() : num =  3566997
# infinite_loop() : num =  3566998
# infinite_loop() : num =  3566999
# infinite_loop() : num =  3567000
# infinite_loop() : num =  3567001
# infinite_loop() : num =  3567002
# infinite_loop() : num =  3567003
# infinite_loop() : num =  3567004
# infinite_loop() : num =  3567005
# infinite_loop() : num =  3567006
# infinite_loop() : num =  3567007
# infinite_loop() : num =  3567008
# infinite_loop() : num =  3567009
# infinite_loop() : num =  3567010
# infinite_loop() : num =  3567011
# infinite_loop() : num =  3567012
# infinite_loop() : num =  3567013
# infinite_loop() : num =  3567014
# infinite_loop() : num =  3567015
# infinite_loop() : num =  3567016
# infinite_loop() : num =  3567017
# infinite_loop() : num =  3567018
# infinite_loop() : num =  3567019
# infinite_loop() : num =  3567020
# infinite_loop() : num =  3567021
# infinite_loop() : num =  3567022
# infinite_loop() : num =  3567023
# infinite_loop() : num =  3567024
# infinite_loop() : num =  3567025
# infinite_loop() : num =  3567026
# infinite_loop() : num =  3567027
# infinite_loop() : num =  3567028
# infinite_loop() : num =  3567029
# infinite_loop() : num =  3567030
# infinite_loop() : num =  3567031
# infinite_loop() : num =  3567032
# infinite_loop() : num =  3567033
# infinite_loop() : num =  3567034
# infinite_loop() : num =  3567035
# infinite_loop() : num =  3567036
# infinite_loop() : num =  3567037
# infinite_loop() : num =  3567038
# infinite_loop() : num =  3567039
# infinite_loop() : num =  3567040
# infinite_loop() : num =  3567041
# infinite_loop() : num =  3567042
# infinite_loop() : num =  3567043
# infinite_loop() : num =  3567044
# infinite_loop() : num =  3567045
# infinite_loop() : num =  3567046
# infinite_loop() : num =  3567047
# infinite_loop() : num =  3567048
# infinite_loop() : num =  3567049
# infinite_loop() : num =  3567050
# infinite_loop() : num =  3567051
# infinite_loop() : num =  3567052
# infinite_loop() : num =  3567053
# infinite_loop() : num =  3567054
# infinite_loop() : num =  3567055
# infinite_loop() : num =  3567056
# infinite_loop() : num =  3567057
# infinite_loop() : num =  3567058
# infinite_loop() : num =  3567059
# infinite_loop() : num =  3567060
# infinite_loop() : num =  3567061
# infinite_loop() : num =  3567062
# infinite_loop() : num =  3567063
# infinite_loop() : num =  3567064
# infinite_loop() : num =  3567065
# infinite_loop() : num =  3567066
# infinite_loop() : num =  3567067
# infinite_loop() : num =  3567068
# infinite_loop() : num =  3567069
# infinite_loop() : num =  3567070
# infinite_loop() : num =  3567071
# infinite_loop() : num =  3567072
# infinite_loop() : num =  3567073
# infinite_loop() : num =  3567074
# infinite_loop() : num =  3567075
# infinite_loop() : num =  3567076
# infinite_loop() : num =  3567077
# infinite_loop() : num =  3567078
# infinite_loop() : num =  3567079
# infinite_loop() : num =  3567080
# infinite_loop() : num =  3567081
# infinite_loop() : num =  3567082
# infinite_loop() : num =  3567083
# infinite_loop() : num =  3567084
# infinite_loop() : num =  3567085
# infinite_loop() : num =  3567086
# infinite_loop() : num =  3567087
# infinite_loop() : num =  3567088
# infinite_loop() : num =  3567089
# infinite_loop() : num =  3567090
# infinite_loop() : num =  3567091
# infinite_loop() : num =  3567092
# infinite_loop() : num =  3567093
# infinite_loop() : num =  3567094
# infinite_loop() : num =  3567095
# infinite_loop() : num =  3567096
# infinite_loop() : num =  3567097
# infinite_loop() : num =  3567098
# infinite_loop() : num =  3567099
# infinite_loop() : num =  3567100
# infinite_loop() : num =  3567101
# infinite_loop() : num =  3567102
# infinite_loop() : num =  3567103
# infinite_loop() : num =  3567104
# infinite_loop() : num =  3567105
# infinite_loop() : num =  3567106
# infinite_loop() : num =  3567107
# infinite_loop() : num =  3567108
# infinite_loop() : num =  3567109
# infinite_loop() : num =  3567110
# infinite_loop() : num =  3567111
# infinite_loop() : num =  3567112
# infinite_loop() : num =  3567113
# infinite_loop() : num =  3567114
# infinite_loop() : num =  3567115
# infinite_loop() : num =  3567116
# infinite_loop() : num =  3567117
# infinite_loop() : num =  3567118
# infinite_loop() : num =  3567119
# infinite_loop() : num =  3567120
# infinite_loop() : num =  3567121
# infinite_loop() : num =  3567122
# infinite_loop() : num =  3567123
# infinite_loop() : num =  3567124
# infinite_loop() : num =  3567125
# infinite_loop() : num =  3567126
# infinite_loop() : num =  3567127
# infinite_loop() : num =  3567128
# infinite_loop() : num =  3567129
# infinite_loop() : num =  3567130
# infinite_loop() : num =  3567131
# infinite_loop() : num =  3567132
# infinite_loop() : num =  3567133
# infinite_loop() : num =  3567134
# infinite_loop() : num =  3567135
# infinite_loop() : num =  3567136
# infinite_loop() : num =  3567137
# infinite_loop() : num =  3567138
# infinite_loop() : num =  3567139
# infinite_loop() : num =  3567140
# infinite_loop() : num =  3567141
# infinite_loop() : num =  3567142
# infinite_loop() : num =  3567143
# infinite_loop() : num =  3567144
# infinite_loop() : num =  3567145
# infinite_loop() : num =  3567146
# infinite_loop() : num =  3567147
# infinite_loop() : num =  3567148
# infinite_loop() : num =  3567149
# infinite_loop() : num =  3567150
# infinite_loop() : num =  3567151
# infinite_loop() : num =  3567152
# infinite_loop() : num =  3567153
# infinite_loop() : num =  3567154
# infinite_loop() : num =  3567155
# infinite_loop() : num =  3567156
# infinite_loop() : num =  3567157
# infinite_loop() : num =  3567158
# infinite_loop() : num =  3567159
# infinite_loop() : num =  3567160
# infinite_loop() : num =  3567161
# infinite_loop() : num =  3567162
# infinite_loop() : num =  3567163
# infinite_loop() : num =  3567164
# infinite_loop() : num =  3567165
# infinite_loop() : num =  3567166
# infinite_loop() : num =  3567167
# infinite_loop() : num =  3567168
# infinite_loop() : num =  3567169
# infinite_loop() : num =  3567170
# infinite_loop() : num =  3567171
# infinite_loop() : num =  3567172
# infinite_loop() : num =  3567173
# infinite_loop() : num =  3567174
# infinite_loop() : num =  3567175
# infinite_loop() : num =  3567176
# infinite_loop() : num =  3567177
# infinite_loop() : num =  3567178
# infinite_loop() : num =  3567179
# infinite_loop() : num =  3567180
# infinite_loop() : num =  3567181
# infinite_loop() : num =  3567182
# infinite_loop() : num =  3567183
# infinite_loop() : num =  3567184
# infinite_loop() : num =  3567185
# infinite_loop() : num =  3567186
# infinite_loop() : num =  3567187
# infinite_loop() : num =  3567188
# infinite_loop() : num =  3567189
# infinite_loop() : num =  3567190
# infinite_loop() : num =  3567191
# infinite_loop() : num =  3567192
# infinite_loop() : num =  3567193
# infinite_loop() : num =  3567194
# infinite_loop() : num =  3567195
# infinite_loop() : num =  3567196
# infinite_loop() : num =  3567197
# infinite_loop() : num =  3567198
# infinite_loop() : num =  3567199
# infinite_loop() : num =  3567200
# infinite_loop() : num =  3567201
# infinite_loop() : num =  3567202
# infinite_loop() : num =  3567203
# infinite_loop() : num =  3567204
# infinite_loop() : num =  3567205
# infinite_loop() : num =  3567206
# infinite_loop() : num =  3567207
# infinite_loop() : num =  3567208
# infinite_loop() : num =  3567209
# infinite_loop() : num =  3567210
# infinite_loop() : num =  3567211
# infinite_loop() : num =  3567212
# infinite_loop() : num =  3567213
# infinite_loop() : num =  3567214
# infinite_loop() : num =  3567215
# infinite_loop() : num =  3567216
# infinite_loop() : num =  3567217
# infinite_loop() : num =  3567218
# infinite_loop() : num =  3567219
# infinite_loop() : num =  3567220
# infinite_loop() : num =  3567221
# infinite_loop() : num =  3567222
# infinite_loop() : num =  3567223
# infinite_loop() : num =  3567224
# infinite_loop() : num =  3567225
# infinite_loop() : num =  3567226
# infinite_loop() : num =  3567227
# infinite_loop() : num =  3567228
# infinite_loop() : num =  3567229
# infinite_loop() : num =  3567230
# infinite_loop() : num =  3567231
# infinite_loop() : num =  3567232
# infinite_loop() : num =  3567233
# infinite_loop() : num =  3567234
# infinite_loop() : num =  3567235
# infinite_loop() : num =  3567236
# infinite_loop() : num =  3567237
# infinite_loop() : num =  3567238
# infinite_loop() : num =  3567239
# infinite_loop() : num =  3567240
# infinite_loop() : num =  3567241
# infinite_loop() : num =  3567242
# infinite_loop() : num =  3567243
# infinite_loop() : num =  3567244
# infinite_loop() : num =  3567245
# infinite_loop() : num =  3567246
# infinite_loop() : num =  3567247
# infinite_loop() : num =  3567248
# infinite_loop() : num =  3567249
# infinite_loop() : num =  3567250
# infinite_loop() : num =  3567251
# infinite_loop() : num =  3567252
# infinite_loop() : num =  3567253
# infinite_loop() : num =  3567254
# infinite_loop() : num =  3567255
# infinite_loop() : num =  3567256
# infinite_loop() : num =  3567257
# infinite_loop() : num =  3567258
# infinite_loop() : num =  3567259
# infinite_loop() : num =  3567260
# infinite_loop() : num =  3567261
# infinite_loop() : num =  3567262
# infinite_loop() : num =  3567263
# infinite_loop() : num =  3567264
# infinite_loop() : num =  3567265
# infinite_loop() : num =  3567266
# infinite_loop() : num =  3567267
# infinite_loop() : num =  3567268
# infinite_loop() : num =  3567269
# infinite_loop() : num =  3567270
# infinite_loop() : num =  3567271
# infinite_loop() : num =  3567272
# infinite_loop() : num =  3567273
# infinite_loop() : num =  3567274
# infinite_loop() : num =  3567275
# infinite_loop() : num =  3567276
# infinite_loop() : num =  3567277
# infinite_loop() : num =  3567278
# infinite_loop() : num =  3567279
# infinite_loop() : num =  3567280
# infinite_loop() : num =  3567281
# infinite_loop() : num =  3567282
# infinite_loop() : num =  3567283
# infinite_loop() : num =  3567284
# infinite_loop() : num =  3567285
# infinite_loop() : num =  3567286
# infinite_loop() : num =  3567287
# infinite_loop() : num =  3567288
# infinite_loop() : num =  3567289
# infinite_loop() : num =  3567290
# infinite_loop() : num =  3567291
# infinite_loop() : num =  3567292
# infinite_loop() : num =  3567293
# infinite_loop() : num =  3567294
# infinite_loop() : num =  3567295
# infinite_loop() : num =  3567296
# infinite_loop() : num =  3567297
# infinite_loop() : num =  3567298
# infinite_loop() : num =  3567299
# infinite_loop() : num =  3567300
# infinite_loop() : num =  3567301
# infinite_loop() : num =  3567302
# infinite_loop() : num =  3567303
# infinite_loop() : num =  3567304
# infinite_loop() : num =  3567305
# infinite_loop() : num =  3567306
# infinite_loop() : num =  3567307
# infinite_loop() : num =  3567308
# infinite_loop() : num =  3567309
# infinite_loop() : num =  3567310
# infinite_loop() : num =  3567311
# infinite_loop() : num =  3567312
# infinite_loop() : num =  3567313
# infinite_loop() : num =  3567314
# infinite_loop() : num =  3567315
# infinite_loop() : num =  3567316
# infinite_loop() : num =  3567317
# infinite_loop() : num =  3567318
# infinite_loop() : num =  3567319
# infinite_loop() : num =  3567320
# infinite_loop() : num =  3567321
# infinite_loop() : num =  3567322
# infinite_loop() : num =  3567323
# infinite_loop() : num =  3567324
# infinite_loop() : num =  3567325
# infinite_loop() : num =  3567326
# infinite_loop() : num =  3567327
# infinite_loop() : num =  3567328
# infinite_loop() : num =  3567329
# infinite_loop() : num =  3567330
# infinite_loop() : num =  3567331
# infinite_loop() : num =  3567332
# infinite_loop() : num =  3567333
# infinite_loop() : num =  3567334
# infinite_loop() : num =  3567335
# infinite_loop() : num =  3567336
# infinite_loop() : num =  3567337
# infinite_loop() : num =  3567338
# infinite_loop() : num =  3567339
# infinite_loop() : num =  3567340
# infinite_loop() : num =  3567341
# infinite_loop() : num =  3567342
# infinite_loop() : num =  3567343
# infinite_loop() : num =  3567344
# infinite_loop() : num =  3567345
# infinite_loop() : num =  3567346
# infinite_loop() : num =  3567347
# infinite_loop() : num =  3567348
# infinite_loop() : num =  3567349
# infinite_loop() : num =  3567350
# infinite_loop() : num =  3567351
# infinite_loop() : num =  3567352
# infinite_loop() : num =  3567353
# infinite_loop() : num =  3567354
# infinite_loop() : num =  3567355
# infinite_loop() : num =  3567356
# infinite_loop() : num =  3567357
# infinite_loop() : num =  3567358
# infinite_loop() : num =  3567359
# infinite_loop() : num =  3567360
# infinite_loop() : num =  3567361
# infinite_loop() : num =  3567362
# infinite_loop() : num =  3567363
# infinite_loop() : num =  3567364
# infinite_loop() : num =  3567365
# infinite_loop() : num =  3567366
# infinite_loop() : num =  3567367
# infinite_loop() : num =  3567368
# infinite_loop() : num =  3567369
# infinite_loop() : num =  3567370
# infinite_loop() : num =  3567371
# infinite_loop() : num =  3567372
# infinite_loop() : num =  3567373
# infinite_loop() : num =  3567374
# infinite_loop() : num =  3567375
# infinite_loop() : num =  3567376
# infinite_loop() : num =  3567377
# infinite_loop() : num =  3567378
# infinite_loop() : num =  3567379
# infinite_loop() : num =  3567380
# infinite_loop() : num =  3567381
# infinite_loop() : num =  3567382
# infinite_loop() : num =  3567383
# infinite_loop() : num =  3567384
# infinite_loop() : num =  3567385
# infinite_loop() : num =  3567386
# infinite_loop() : num =  3567387
# infinite_loop() : num =  3567388
# infinite_loop() : num =  3567389
# infinite_loop() : num =  3567390
# infinite_loop() : num =  3567391
# infinite_loop() : num =  3567392
# infinite_loop() : num =  3567393
# infinite_loop() : num =  3567394
# infinite_loop() : num =  3567395
# infinite_loop() : num =  3567396
# infinite_loop() : num =  3567397
# infinite_loop() : num =  3567398
# infinite_loop() : num =  3567399
# infinite_loop() : num =  3567400
# infinite_loop() : num =  3567401
# infinite_loop() : num =  3567402
# infinite_loop() : num =  3567403
# infinite_loop() : num =  3567404
# infinite_loop() : num =  3567405
# infinite_loop() : num =  3567406
# infinite_loop() : num =  3567407
# infinite_loop() : num =  3567408
# infinite_loop() : num =  3567409
# infinite_loop() : num =  3567410
# infinite_loop() : num =  3567411
# infinite_loop() : num =  3567412
# infinite_loop() : num =  3567413
# infinite_loop() : num =  3567414
# infinite_loop() : num =  3567415
# infinite_loop() : num =  3567416
# infinite_loop() : num =  3567417
# infinite_loop() : num =  3567418
# infinite_loop() : num =  3567419
# infinite_loop() : num =  3567420
# infinite_loop() : num =  3567421
# infinite_loop() : num =  3567422
# infinite_loop() : num =  3567423
# infinite_loop() : num =  3567424
# infinite_loop() : num =  3567425
# infinite_loop() : num =  3567426
# infinite_loop() : num =  3567427
# infinite_loop() : num =  3567428
# infinite_loop() : num =  3567429
# infinite_loop() : num =  3567430
# infinite_loop() : num =  3567431
# infinite_loop() : num =  3567432
# infinite_loop() : num =  3567433
# infinite_loop() : num =  3567434
# infinite_loop() : num =  3567435
# infinite_loop() : num =  3567436
# infinite_loop() : num =  3567437
# infinite_loop() : num =  3567438
# infinite_loop() : num =  3567439
# infinite_loop() : num =  3567440
# infinite_loop() : num =  3567441
# infinite_loop() : num =  3567442
# infinite_loop() : num =  3567443
# infinite_loop() : num =  3567444
# infinite_loop() : num =  3567445
# infinite_loop() : num =  3567446
# infinite_loop() : num =  3567447
# infinite_loop() : num =  3567448
# infinite_loop() : num =  3567449
# infinite_loop() : num =  3567450
# infinite_loop() : num =  3567451
# infinite_loop() : num =  3567452
# infinite_loop() : num =  3567453
# infinite_loop() : num =  3567454
# infinite_loop() : num =  3567455
# infinite_loop() : num =  3567456
# infinite_loop() : num =  3567457
# infinite_loop() : num =  3567458
# infinite_loop() : num =  3567459
# infinite_loop() : num =  3567460
# infinite_loop() : num =  3567461
# infinite_loop() : num =  3567462
# infinite_loop() : num =  3567463
# infinite_loop() : num =  3567464
# infinite_loop() : num =  3567465
# infinite_loop() : num =  3567466
# infinite_loop() : num =  3567467
# infinite_loop() : num =  3567468
# infinite_loop() : num =  3567469
# infinite_loop() : num =  3567470
# infinite_loop() : num =  3567471
# infinite_loop() : num =  3567472
# infinite_loop() : num =  3567473
# infinite_loop() : num =  3567474
# infinite_loop() : num =  3567475
# infinite_loop() : num =  3567476
# infinite_loop() : num =  3567477
# infinite_loop() : num =  3567478
# infinite_loop() : num =  3567479
# infinite_loop() : num =  3567480
# infinite_loop() : num =  3567481
# infinite_loop() : num =  3567482
# infinite_loop() : num =  3567483
# infinite_loop() : num =  3567484
# infinite_loop() : num =  3567485
# infinite_loop() : num =  3567486
# infinite_loop() : num =  3567487
# infinite_loop() : num =  3567488
# infinite_loop() : num =  3567489
# infinite_loop() : num =  3567490
# infinite_loop() : num =  3567491
# infinite_loop() : num =  3567492
# infinite_loop() : num =  3567493
# infinite_loop() : num =  3567494
# infinite_loop() : num =  3567495
# infinite_loop() : num =  3567496
# infinite_loop() : num =  3567497
# infinite_loop() : num =  3567498
# infinite_loop() : num =  3567499
# infinite_loop() : num =  3567500
# infinite_loop() : num =  3567501
# infinite_loop() : num =  3567502
# infinite_loop() : num =  3567503
# infinite_loop() : num =  3567504
# infinite_loop() : num =  3567505
# infinite_loop() : num =  3567506
# infinite_loop() : num =  3567507
# infinite_loop() : num =  3567508
# infinite_loop() : num =  3567509
# infinite_loop() : num =  3567510
# infinite_loop() : num =  3567511
# infinite_loop() : num =  3567512
# infinite_loop() : num =  3567513
# infinite_loop() : num =  3567514
# infinite_loop() : num =  3567515
# infinite_loop() : num =  3567516
# infinite_loop() : num =  3567517
# infinite_loop() : num =  3567518
# infinite_loop() : num =  3567519
# infinite_loop() : num =  3567520
# infinite_loop() : num =  3567521
# infinite_loop() : num =  3567522
# infinite_loop() : num =  3567523
# infinite_loop() : num =  3567524
# infinite_loop() : num =  3567525
# infinite_loop() : num =  3567526
# infinite_loop() : num =  3567527
# infinite_loop() : num =  3567528
# infinite_loop() : num =  3567529
# infinite_loop() : num =  3567530
# infinite_loop() : num =  3567531
# infinite_loop() : num =  3567532
# infinite_loop() : num =  3567533
# infinite_loop() : num =  3567534
# infinite_loop() : num =  3567535
# infinite_loop() : num =  3567536
# infinite_loop() : num =  3567537
# infinite_loop() : num =  3567538
# infinite_loop() : num =  3567539
# infinite_loop() : num =  3567540
# infinite_loop() : num =  3567541
# infinite_loop() : num =  3567542
# infinite_loop() : num =  3567543
# infinite_loop() : num =  3567544
# infinite_loop() : num =  3567545
# infinite_loop() : num =  3567546
# infinite_loop() : num =  3567547
# infinite_loop() : num =  3567548
# infinite_loop() : num =  3567549
# infinite_loop() : num =  3567550
# infinite_loop() : num =  3567551
# infinite_loop() : num =  3567552
# infinite_loop() : num =  3567553
# infinite_loop() : num =  3567554
# infinite_loop() : num =  3567555
# infinite_loop() : num =  3567556
# infinite_loop() : num =  3567557
# infinite_loop() : num =  3567558
# infinite_loop() : num =  3567559
# infinite_loop() : num =  3567560
# infinite_loop() : num =  3567561
# infinite_loop() : num =  3567562
# infinite_loop() : num =  3567563
# infinite_loop() : num =  3567564
# infinite_loop() : num =  3567565
# infinite_loop() : num =  3567566
# infinite_loop() : num =  3567567
# infinite_loop() : num =  3567568
# infinite_loop() : num =  3567569
# infinite_loop() : num =  3567570
# infinite_loop() : num =  3567571
# infinite_loop() : num =  3567572
# infinite_loop() : num =  3567573
# infinite_loop() : num =  3567574
# infinite_loop() : num =  3567575
# infinite_loop() : num =  3567576
# infinite_loop() : num =  3567577
# infinite_loop() : num =  3567578
# infinite_loop() : num =  3567579
# infinite_loop() : num =  3567580
# infinite_loop() : num =  3567581
# infinite_loop() : num =  3567582
# infinite_loop() : num =  3567583
# infinite_loop() : num =  3567584
# infinite_loop() : num =  3567585
# infinite_loop() : num =  3567586
# infinite_loop() : num =  3567587
# infinite_loop() : num =  3567588
# infinite_loop() : num =  3567589
# infinite_loop() : num =  3567590
# infinite_loop() : num =  3567591
# infinite_loop() : num =  3567592
# infinite_loop() : num =  3567593
# infinite_loop() : num =  3567594
# infinite_loop() : num =  3567595
# infinite_loop() : num =  3567596
# infinite_loop() : num =  3567597
# infinite_loop() : num =  3567598
# infinite_loop() : num =  3567599
# infinite_loop() : num =  3567600
# infinite_loop() : num =  3567601
# infinite_loop() : num =  3567602
# infinite_loop() : num =  3567603
# infinite_loop() : num =  3567604
# infinite_loop() : num =  3567605
# infinite_loop() : num =  3567606
# infinite_loop() : num =  3567607
# infinite_loop() : num =  3567608
# infinite_loop() : num =  3567609
# infinite_loop() : num =  3567610
# infinite_loop() : num =  3567611
# infinite_loop() : num =  3567612
# infinite_loop() : num =  3567613
# infinite_loop() : num =  3567614
# infinite_loop() : num =  3567615
# infinite_loop() : num =  3567616
# infinite_loop() : num =  3567617
# infinite_loop() : num =  3567618
# infinite_loop() : num =  3567619
# infinite_loop() : num =  3567620
# infinite_loop() : num =  3567621
# infinite_loop() : num =  3567622
# infinite_loop() : num =  3567623
# infinite_loop() : num =  3567624
# infinite_loop() : num =  3567625
# infinite_loop() : num =  3567626
# infinite_loop() : num =  3567627
# infinite_loop() : num =  3567628
# infinite_loop() : num =  3567629
# infinite_loop() : num =  3567630
# infinite_loop() : num =  3567631
# infinite_loop() : num =  3567632
# infinite_loop() : num =  3567633
# infinite_loop() : num =  3567634
# infinite_loop() : num =  3567635
# infinite_loop() : num =  3567636
# infinite_loop() : num =  3567637
# infinite_loop() : num =  3567638
# infinite_loop() : num =  3567639
# infinite_loop() : num =  3567640
# infinite_loop() : num =  3567641
# infinite_loop() : num =  3567642
# infinite_loop() : num =  3567643
# infinite_loop() : num =  3567644
# infinite_loop() : num =  3567645
# infinite_loop() : num =  3567646
# infinite_loop() : num =  3567647
# infinite_loop() : num =  3567648
# infinite_loop() : num =  3567649
# infinite_loop() : num =  3567650
# infinite_loop() : num =  3567651
# infinite_loop() : num =  3567652
# infinite_loop() : num =  3567653
# infinite_loop() : num =  3567654
# infinite_loop() : num =  3567655
# infinite_loop() : num =  3567656
# infinite_loop() : num =  3567657
# infinite_loop() : num =  3567658
# infinite_loop() : num =  3567659
# infinite_loop() : num =  3567660
# infinite_loop() : num =  3567661
# infinite_loop() : num =  3567662
# infinite_loop() : num =  3567663
# infinite_loop() : num =  3567664
# infinite_loop() : num =  3567665
# infinite_loop() : num =  3567666
# infinite_loop() : num =  3567667
# infinite_loop() : num =  3567668
# infinite_loop() : num =  3567669
# infinite_loop() : num =  3567670
# infinite_loop() : num =  3567671
# infinite_loop() : num =  3567672
# infinite_loop() : num =  3567673
# infinite_loop() : num =  3567674
# infinite_loop() : num =  3567675
# infinite_loop() : num =  3567676
# infinite_loop() : num =  3567677
# infinite_loop() : num =  3567678
# infinite_loop() : num =  3567679
# infinite_loop() : num =  3567680
# infinite_loop() : num =  3567681
# infinite_loop() : num =  3567682
# infinite_loop() : num =  3567683
# infinite_loop() : num =  3567684
# infinite_loop() : num =  3567685
# infinite_loop() : num =  3567686
# infinite_loop() : num =  3567687
# infinite_loop() : num =  3567688
# infinite_loop() : num =  3567689
# infinite_loop() : num =  3567690
# infinite_loop() : num =  3567691
# infinite_loop() : num =  3567692
# infinite_loop() : num =  3567693
# infinite_loop() : num =  3567694
# infinite_loop() : num =  3567695
# infinite_loop() : num =  3567696
# infinite_loop() : num =  3567697
# infinite_loop() : num =  3567698
# infinite_loop() : num =  3567699
# infinite_loop() : num =  3567700
# infinite_loop() : num =  3567701
# infinite_loop() : num =  3567702
# infinite_loop() : num =  3567703
# infinite_loop() : num =  3567704
# infinite_loop() : num =  3567705
# infinite_loop() : num =  3567706
# infinite_loop() : num =  3567707
# infinite_loop() : num =  3567708
# infinite_loop() : num =  3567709
# infinite_loop() : num =  3567710
# infinite_loop() : num =  3567711
# infinite_loop() : num =  3567712
# infinite_loop() : num =  3567713
# infinite_loop() : num =  3567714
# infinite_loop() : num =  3567715
# infinite_loop() : num =  3567716
# infinite_loop() : num =  3567717
# infinite_loop() : num =  3567718
# infinite_loop() : num =  3567719
# infinite_loop() : num =  3567720
# infinite_loop() : num =  3567721
# infinite_loop() : num =  3567722
# infinite_loop() : num =  3567723
# infinite_loop() : num =  3567724
# infinite_loop() : num =  3567725
# infinite_loop() : num =  3567726
# infinite_loop() : num =  3567727
# infinite_loop() : num =  3567728
# infinite_loop() : num =  3567729
# infinite_loop() : num =  3567730
# infinite_loop() : num =  3567731
# infinite_loop() : num =  3567732
# infinite_loop() : num =  3567733
# infinite_loop() : num =  3567734
# infinite_loop() : num =  3567735
# infinite_loop() : num =  3567736
# infinite_loop() : num =  3567737
# infinite_loop() : num =  3567738
# infinite_loop() : num =  3567739
# infinite_loop() : num =  3567740
# infinite_loop() : num =  3567741
# infinite_loop() : num =  3567742
# infinite_loop() : num =  3567743
# infinite_loop() : num =  3567744
# infinite_loop() : num =  3567745
# infinite_loop() : num =  3567746
# infinite_loop() : num =  3567747
# infinite_loop() : num =  3567748
# infinite_loop() : num =  3567749
# infinite_loop() : num =  3567750
# infinite_loop() : num =  3567751
# infinite_loop() : num =  3567752
# infinite_loop() : num =  3567753
# infinite_loop() : num =  3567754
# infinite_loop() : num =  3567755
# infinite_loop() : num =  3567756
# infinite_loop() : num =  3567757
# infinite_loop() : num =  3567758
# infinite_loop() : num =  3567759
# infinite_loop() : num =  3567760
# infinite_loop() : num =  3567761
# infinite_loop() : num =  3567762
# infinite_loop() : num =  3567763
# infinite_loop() : num =  3567764
# infinite_loop() : num =  3567765
# infinite_loop() : num =  3567766
# infinite_loop() : num =  3567767
# infinite_loop() : num =  3567768
# infinite_loop() : num =  3567769
# infinite_loop() : num =  3567770
# infinite_loop() : num =  3567771
# infinite_loop() : num =  3567772
# infinite_loop() : num =  3567773
# infinite_loop() : num =  3567774
# infinite_loop() : num =  3567775
# infinite_loop() : num =  3567776
# infinite_loop() : num =  3567777
# infinite_loop() : num =  3567778
# infinite_loop() : num =  3567779
# infinite_loop() : num =  3567780
# infinite_loop() : num =  3567781
# infinite_loop() : num =  3567782
# infinite_loop() : num =  3567783
# infinite_loop() : num =  3567784
# infinite_loop() : num =  3567785
# infinite_loop() : num =  3567786
# infinite_loop() : num =  3567787
# infinite_loop() : num =  3567788
# infinite_loop() : num =  3567789
# infinite_loop() : num =  3567790
# infinite_loop() : num =  3567791
# infinite_loop() : num =  3567792
# infinite_loop() : num =  3567793
# infinite_loop() : num =  3567794
# infinite_loop() : num =  3567795
# infinite_loop() : num =  3567796
# infinite_loop() : num =  3567797
# infinite_loop() : num =  3567798
# infinite_loop() : num =  3567799
# infinite_loop() : num =  3567800
# infinite_loop() : num =  3567801
# infinite_loop() : num =  3567802
# infinite_loop() : num =  3567803
# infinite_loop() : num =  3567804
# infinite_loop() : num =  3567805
# infinite_loop() : num =  3567806
# infinite_loop() : num =  3567807
# infinite_loop() : num =  3567808
# infinite_loop() : num =  3567809
# infinite_loop() : num =  3567810
# infinite_loop() : num =  3567811
# infinite_loop() : num =  3567812
# infinite_loop() : num =  3567813
# infinite_loop() : num =  3567814
# infinite_loop() : num =  3567815
# infinite_loop() : num =  3567816
# infinite_loop() : num =  3567817
# infinite_loop() : num =  3567818
# infinite_loop() : num =  3567819
# infinite_loop() : num =  3567820
# infinite_loop() : num =  3567821
# infinite_loop() : num =  3567822
# infinite_loop() : num =  3567823
# infinite_loop() : num =  3567824
# infinite_loop() : num =  3567825
# infinite_loop() : num =  3567826
# infinite_loop() : num =  3567827
# infinite_loop() : num =  3567828
# infinite_loop() : num =  3567829
# infinite_loop() : num =  3567830
# infinite_loop() : num =  3567831
# infinite_loop() : num =  3567832
# infinite_loop() : num =  3567833
# infinite_loop() : num =  3567834
# infinite_loop() : num =  3567835
# infinite_loop() : num =  3567836
# infinite_loop() : num =  3567837
# infinite_loop() : num =  3567838
# infinite_loop() : num =  3567839
# infinite_loop() : num =  3567840
# infinite_loop() : num =  3567841
# infinite_loop() : num =  3567842
# infinite_loop() : num =  3567843
# infinite_loop() : num =  3567844
# infinite_loop() : num =  3567845
# infinite_loop() : num =  3567846
# infinite_loop() : num =  3567847
# infinite_loop() : num =  3567848
# infinite_loop() : num =  3567849
# infinite_loop() : num =  3567850
# infinite_loop() : num =  3567851
# infinite_loop() : num =  3567852
# infinite_loop() : num =  3567853
# infinite_loop() : num =  3567854
# infinite_loop() : num =  3567855
# infinite_loop() : num =  3567856
# infinite_loop() : num =  3567857
# infinite_loop() : num =  3567858
# infinite_loop() : num =  3567859
# infinite_loop() : num =  3567860
# infinite_loop() : num =  3567861
# infinite_loop() : num =  3567862
# infinite_loop() : num =  3567863
# infinite_loop() : num =  3567864
# infinite_loop() : num =  3567865
# infinite_loop() : num =  3567866
# infinite_loop() : num =  3567867
# infinite_loop() : num =  3567868
# infinite_loop() : num =  3567869
# infinite_loop() : num =  3567870
# infinite_loop() : num =  3567871
# infinite_loop() : num =  3567872
# infinite_loop() : num =  3567873
# infinite_loop() : num =  3567874
# infinite_loop() : num =  3567875
# infinite_loop() : num =  3567876
# infinite_loop() : num =  3567877
# infinite_loop() : num =  3567878
# infinite_loop() : num =  3567879
# infinite_loop() : num =  3567880
# infinite_loop() : num =  3567881
# infinite_loop() : num =  3567882
# infinite_loop() : num =  3567883
# infinite_loop() : num =  3567884
# infinite_loop() : num =  3567885
# infinite_loop() : num =  3567886
# infinite_loop() : num =  3567887
# infinite_loop() : num =  3567888
# infinite_loop() : num =  3567889
# infinite_loop() : num =  3567890
# infinite_loop() : num =  3567891
# infinite_loop() : num =  3567892
# infinite_loop() : num =  3567893
# infinite_loop() : num =  3567894
# infinite_loop() : num =  3567895
# infinite_loop() : num =  3567896
# infinite_loop() : num =  3567897
# infinite_loop() : num =  3567898
# infinite_loop() : num =  3567899
# infinite_loop() : num =  3567900
# infinite_loop() : num =  3567901
# infinite_loop() : num =  3567902
# infinite_loop() : num =  3567903
# infinite_loop() : num =  3567904
# infinite_loop() : num =  3567905
# infinite_loop() : num =  3567906
# infinite_loop() : num =  3567907
# infinite_loop() : num =  3567908
# infinite_loop() : num =  3567909
# infinite_loop() : num =  3567910
# infinite_loop() : num =  3567911
# infinite_loop() : num =  3567912
# infinite_loop() : num =  3567913
# infinite_loop() : num =  3567914
# infinite_loop() : num =  3567915
# infinite_loop() : num =  3567916
# infinite_loop() : num =  3567917
# infinite_loop() : num =  3567918
# infinite_loop() : num =  3567919
# infinite_loop() : num =  3567920
# infinite_loop() : num =  3567921
# infinite_loop() : num =  3567922
# infinite_loop() : num =  3567923
# infinite_loop() : num =  3567924
# infinite_loop() : num =  3567925
# infinite_loop() : num =  3567926
# infinite_loop() : num =  3567927
# infinite_loop() : num =  3567928
# infinite_loop() : num =  3567929
# infinite_loop() : num =  3567930
# infinite_loop() : num =  3567931
# infinite_loop() : num =  3567932
# infinite_loop() : num =  3567933
# infinite_loop() : num =  3567934
# infinite_loop() : num =  3567935
# infinite_loop() : num =  3567936
# infinite_loop() : num =  3567937
# infinite_loop() : num =  3567938
# infinite_loop() : num =  3567939
# infinite_loop() : num =  3567940
# infinite_loop() : num =  3567941
# infinite_loop() : num =  3567942
# infinite_loop() : num =  3567943
# infinite_loop() : num =  3567944
# infinite_loop() : num =  3567945
# infinite_loop() : num =  3567946
# infinite_loop() : num =  3567947
# infinite_loop() : num =  3567948
# infinite_loop() : num =  3567949
# infinite_loop() : num =  3567950
# infinite_loop() : num =  3567951
# infinite_loop() : num =  3567952
# infinite_loop() : num =  3567953
# infinite_loop() : num =  3567954
# infinite_loop() : num =  3567955
# infinite_loop() : num =  3567956
# infinite_loop() : num =  3567957
# infinite_loop() : num =  3567958
# infinite_loop() : num =  3567959
# infinite_loop() : num =  3567960
# infinite_loop() : num =  3567961
# infinite_loop() : num =  3567962
# infinite_loop() : num =  3567963
# ...
# infinite_loop() : num =  3571059
# infinite_loop() : num =  3571060
# infinite_loop() : num =  3571061
# infinite_loop() : num =  3571062
# infinite_loop() : num =  3571063
# infinite_loop() : num =  3571064
# infinite_loop() : num =  3571065
# infinite_loop() : num =  3571066
# infinite_loop() : num =  3571067
# infinite_loop() : num =  3571068
# infinite_loop() : num =  3571069
# infinite_loop() : num =  3571070
# infinite_loop() : num =  3571071
# infinite_loop() : num =  3571072
# infinite_loop() : num =  3571073
# infinite_loop() : num =  3571074
# infinite_loop() : num =  3571075
# infinite_loop() : num =  3571076
# infinite_loop() : num =  3571077
# infinite_loop() : num =  3571078
# infinite_loop() : num =  3571079
# infinite_loop() : num =  3571080
# infinite_loop() : num =  3571081
# infinite_loop() : num =  3571082
# infinite_loop() : num =  3571083
# infinite_loop() : num =  3571084
# infinite_loop() : num =  3571085
# infinite_loop() : num =  3571086
# infinite_loop() : num =  3571087
# infinite_loop() : num =  3571088
# infinite_loop() : num =  3571089
# infinite_loop() : num =  3571090
# infinite_loop() : num =  3571091
# infinite_loop() : num =  3571092
# infinite_loop() : num =  3571093
# infinite_loop() : num =  3571094
# infinite_loop() : num =  3571095
# infinite_loop() : num =  3571096
# infinite_loop() : num =  3571097
# infinite_loop() : num =  3571098
# infinite_loop() : num =  3571099
# infinite_loop() : num =  3571100
# infinite_loop() : num =  3571101
# infinite_loop() : num =  3571102
# infinite_loop() : num =  3571103
# infinite_loop() : num =  3571104
# infinite_loop() : num =  3571105
# infinite_loop() : num =  3571106
# infinite_loop() : num =  3571107
# infinite_loop() : num =  3571108
# infinite_loop() : num =  3571109
# infinite_loop() : num =  3571110
# infinite_loop() : num =  3571111
# infinite_loop() : num =  3571112
# infinite_loop() : num =  3571113
# infinite_loop() : num =  3571114
# infinite_loop() : num =  3571115
# infinite_loop() : num =  3571116
# infinite_loop() : num =  3571117
# infinite_loop() : num =  3571118
# infinite_loop() : num =  3571119
# infinite_loop() : num =  3571120
# infinite_loop() : num =  3571121
# infinite_loop() : num =  3571122
# infinite_loop() : num =  3571123
# infinite_loop() : num =  3571124
# infinite_loop() : num =  3571125
# infinite_loop() : num =  3571126
# infinite_loop() : num =  3571127
# infinite_loop() : num =  3571128
# infinite_loop() : num =  3571129
# infinite_loop() : num =  3571130
# infinite_loop() : num =  3571131
# infinite_loop() : num =  3571132
# infinite_loop() : num =  3571133
# infinite_loop() : num =  3571134
# infinite_loop() : num =  3571135
# infinite_loop() : num =  3571136
# infinite_loop() : num =  3571137
# infinite_loop() : num =  3571138
# infinite_loop() : num =  3571139
# infinite_loop() : num =  3571140
# infinite_loop() : num =  3571141
# infinite_loop() : num =  3571142
# infinite_loop() : num =  3571143
# infinite_loop() : num =  3571144
# infinite_loop() : num =  3571145
# infinite_loop() : num =  3571146
# infinite_loop() : num =  3571147
# infinite_loop() : num =  3571148
# infinite_loop() : num =  3571149
# infinite_loop() : num =  3571150
# infinite_loop() : num =  3571151
# infinite_loop() : num =  3571152
# infinite_loop() : num =  3571153
# infinite_loop() : num =  3571154
# infinite_loop() : num =  3571155
# infinite_loop() : num =  3571156
# infinite_loop() : num =  3571157
# infinite_loop() : num =  3571158
# infinite_loop() : num =  3571159
# infinite_loop() : num =  3571160
# infinite_loop() : num =  3571161
# infinite_loop() : num =  3571162
# infinite_loop() : num =  3571163
# infinite_loop() : num =  3571164
# infinite_loop() : num =  3571165
# infinite_loop() : num =  3571166
# infinite_loop() : num =  3571167
# infinite_loop() : num =  3571168
# infinite_loop() : num =  3571169
# infinite_loop() : num =  3571170
# infinite_loop() : num =  3571171
# infinite_loop() : num =  3571172
# infinite_loop() : num =  3571173
# infinite_loop() : num =  3571174
# infinite_loop() : num =  3571175
# infinite_loop() : num =  3571176
# infinite_loop() : num =  3571177
# infinite_loop() : num =  3571178
# infinite_loop() : num =  3571179
# infinite_loop() : num =  3571180
# infinite_loop() : num =  3571181
# infinite_loop() : num =  3571182
# infinite_loop() : num =  3571183
# infinite_loop() : num =  3571184
# infinite_loop() : num =  3571185
# infinite_loop() : num =  3571186
# infinite_loop() : num =  3571187
# infinite_loop() : num =  3571188
# infinite_loop() : num =  3571189
# infinite_loop() : num =  3571190
# infinite_loop() : num =  3571191
# infinite_loop() : num =  3571192
# infinite_loop() : num =  3571193
# infinite_loop() : num =  3571194
# infinite_loop() : num =  3571195
# infinite_loop() : num =  3571196
# infinite_loop() : num =  3571197
# infinite_loop() : num =  3571198
# infinite_loop() : num =  3571199
# infinite_loop() : num =  3571200
# infinite_loop() : num =  3571201
# infinite_loop() : num =  3571202
# infinite_loop() : num =  3571203
# infinite_loop() : num =  3571204
# infinite_loop() : num =  3571205
# infinite_loop() : num =  3571206
# infinite_loop() : num =  3571207
# infinite_loop() : num =  3571208
# infinite_loop() : num =  3571209
# infinite_loop() : num =  3571210
# infinite_loop() : num =  3571211
# infinite_loop() : num =  3571212
# infinite_loop() : num =  3571213
# infinite_loop() : num =  3571214
# infinite_loop() : num =  3571215
# infinite_loop() : num =  3571216
# infinite_loop() : num =  3571217
# infinite_loop() : num =  3571218
# infinite_loop() : num =  3571219
# infinite_loop() : num =  3571220
# infinite_loop() : num =  3571221
# infinite_loop() : num =  3571222
# infinite_loop() : num =  3571223
# infinite_loop() : num =  3571224
# infinite_loop() : num =  3571225
# infinite_loop() : num =  3571226
# infinite_loop() : num =  3571227
# infinite_loop() : num =  3571228
# infinite_loop() : num =  3571229
# infinite_loop() : num =  3571230
# infinite_loop() : num =  3571231
# infinite_loop() : num =  3571232
# infinite_loop() : num =  3571233
# infinite_loop() : num =  3571234
# infinite_loop() : num =  3571235
# infinite_loop() : num =  3571236
# infinite_loop() : num =  3571237
# infinite_loop() : num =  3571238
# infinite_loop() : num =  3571239
# infinite_loop() : num =  3571240
# infinite_loop() : num =  3571241
# infinite_loop() : num =  3571242
# infinite_loop() : num =  3571243
# infinite_loop() : num =  3571244
# infinite_loop() : num =  3571245
# infinite_loop() : num =  3571246
# infinite_loop() : num =  3571247
# infinite_loop() : num =  3571248
# infinite_loop() : num =  3571249
# infinite_loop() : num =  3571250
# infinite_loop() : num =  3571251
# infinite_loop() : num =  3571252
# infinite_loop() : num =  3571253
# infinite_loop() : num =  3571254
# infinite_loop() : num =  3571255
# infinite_loop() : num =  3571256
# infinite_loop() : num =  3571257
# infinite_loop() : num =  3571258
# infinite_loop() : num =  3571259
# infinite_loop() : num =  3571260
# infinite_loop() : num =  3571261
# infinite_loop() : num =  3571262
# infinite_loop() : num =  3571263
# infinite_loop() : num =  3571264
# infinite_loop() : num =  3571265
# infinite_loop() : num =  3571266
# infinite_loop() : num =  3571267
# infinite_loop() : num =  3571268
# infinite_loop() : num =  3571269
# infinite_loop() : num =  3571270
# infinite_loop() : num =  3571271
# infinite_loop() : num =  3571272
# infinite_loop() : num =  3571273
# infinite_loop() : num =  3571274
# infinite_loop() : num =  3571275
# infinite_loop() : num =  3571276
# infinite_loop() : num =  3571277
# infinite_loop() : num =  3571278
# infinite_loop() : num =  3571279
# infinite_loop() : num =  3571280
# infinite_loop() : num =  3571281
# infinite_loop() : num =  3571282
# infinite_loop() : num =  3571283
# infinite_loop() : num =  3571284
# infinite_loop() : num =  3571285
# infinite_loop() : num =  3571286
# infinite_loop() : num =  3571287
# infinite_loop() : num =  3571288
# infinite_loop() : num =  3571289
# infinite_loop() : num =  3571290
# infinite_loop() : num =  3571291
# infinite_loop() : num =  3571292
# infinite_loop() : num =  3571293
# infinite_loop() : num =  3571294
# infinite_loop() : num =  3571295
# infinite_loop() : num =  3571296
# infinite_loop() : num =  3571297
# infinite_loop() : num =  3571298
# infinite_loop() : num =  3571299
# infinite_loop() : num =  3571300
# infinite_loop() : num =  3571301
# infinite_loop() : num =  3571302
# infinite_loop() : num =  3571303
# infinite_loop() : num =  3571304
# infinite_loop() : num =  3571305
# infinite_loop() : num =  3571306
# infinite_loop() : num =  3571307
# infinite_loop() : num =  3571308
# infinite_loop() : num =  3571309
# infinite_loop() : num =  3571310
# infinite_loop() : num =  3571311
# infinite_loop() : num =  3571312
# infinite_loop() : num =  3571313
# infinite_loop() : num =  3571314
# infinite_loop() : num =  3571315
# infinite_loop() : num =  3571316
# infinite_loop() : num =  3571317
# infinite_loop() : num =  3571318
# infinite_loop() : num =  3571319
# infinite_loop() : num =  3571320
# infinite_loop() : num =  3571321
# infinite_loop() : num =  3571322
# infinite_loop() : num =  3571323
# infinite_loop() : num =  3571324
# infinite_loop() : num =  3571325
# infinite_loop() : num =  3571326
# infinite_loop() : num =  3571327
# infinite_loop() : num =  3571328
# infinite_loop() : num =  3571329
# infinite_loop() : num =  3571330
# infinite_loop() : num =  3571331
# infinite_loop() : num =  3571332
# infinite_loop() : num =  3571333
# infinite_loop() : num =  3571334
# infinite_loop() : num =  3571335
# infinite_loop() : num =  3571336
# infinite_loop() : num =  3571337
# infinite_loop() : num =  3571338
# infinite_loop() : num =  3571339
# infinite_loop() : num =  3571340
# infinite_loop() : num =  3571341
# infinite_loop() : num =  3571342
# infinite_loop() : num =  3571343
# infinite_loop() : num =  3571344
# infinite_loop() : num =  3571345
# infinite_loop() : num =  3571346
# infinite_loop() : num =  3571347
# infinite_loop() : num =  3571348
# infinite_loop() : num =  3571349
# infinite_loop() : num =  3571350
# infinite_loop() : num =  3571351
# infinite_loop() : num =  3571352
# infinite_loop() : num =  3571353
# infinite_loop() : num =  3571354
# infinite_loop() : num =  3571355
# infinite_loop() : num =  3571356
# infinite_loop() : num =  3571357
# infinite_loop() : num =  3571358
# infinite_loop() : num =  3571359
# infinite_loop() : num =  3571360
# infinite_loop() : num =  3571361
# infinite_loop() : num =  3571362
# infinite_loop() : num =  3571363
# infinite_loop() : num =  3571364
# infinite_loop() : num =  3571365
# infinite_loop() : num =  3571366
# infinite_loop() : num =  3571367
# infinite_loop() : num =  3571368
# infinite_loop() : num =  3571369
# infinite_loop() : num =  3571370
# infinite_loop() : num =  3571371
# infinite_loop() : num =  3571372
# infinite_loop() : num =  3571373
# infinite_loop() : num =  3571374
# infinite_loop() : num =  3571375
# infinite_loop() : num =  3571376
# infinite_loop() : num =  3571377
# infinite_loop() : num =  3571378
# infinite_loop() : num =  3571379
# infinite_loop() : num =  3571380
# infinite_loop() : num =  3571381
# infinite_loop() : num =  3571382
# infinite_loop() : num =  3571383
# infinite_loop() : num =  3571384
# infinite_loop() : num =  3571385
# infinite_loop() : num =  3571386
# infinite_loop() : num =  3571387
# infinite_loop() : num =  3571388
# infinite_loop() : num =  3571389
# infinite_loop() : num =  3571390
# infinite_loop() : num =  3571391
# infinite_loop() : num =  3571392
# infinite_loop() : num =  3571393
# infinite_loop() : num =  3571394
# infinite_loop() : num =  3571395
# infinite_loop() : num =  3571396
# infinite_loop() : num =  3571397
# infinite_loop() : num =  3571398
# infinite_loop() : num =  3571399
# infinite_loop() : num =  3571400
# infinite_loop() : num =  3571401
# infinite_loop() : num =  3571402
# infinite_loop() : num =  3571403
# infinite_loop() : num =  3571404
# infinite_loop() : num =  3571405
# infinite_loop() : num =  3571406
# infinite_loop() : num =  3571407
# infinite_loop() : num =  3571408
# infinite_loop() : num =  3571409
# infinite_loop() : num =  3571410
# infinite_loop() : num =  3571411
# infinite_loop() : num =  3571412
# infinite_loop() : num =  3571413
# infinite_loop() : num =  3571414
# infinite_loop() : num =  3571415
# infinite_loop() : num =  3571416
# infinite_loop() : num =  3571417
# infinite_loop() : num =  3571418
# infinite_loop() : num =  3571419
# infinite_loop() : num =  3571420
# infinite_loop() : num =  3571421
# infinite_loop() : num =  3571422
# infinite_loop() : num =  3571423
# infinite_loop() : num =  3571424
# infinite_loop() : num =  3571425
# infinite_loop() : num =  3571426
# infinite_loop() : num =  3571427
# infinite_loop() : num =  3571428
# infinite_loop() : num =  3571429
# infinite_loop() : num =  3571430
# infinite_loop() : num =  3571431
# infinite_loop() : num =  3571432
# infinite_loop() : num =  3571433
# infinite_loop() : num =  3571434
# infinite_loop() : num =  3571435
# infinite_loop() : num =  3571436
# infinite_loop() : num =  3571437
# infinite_loop() : num =  3571438
# infinite_loop() : num =  3571439
# infinite_loop() : num =  3571440
# infinite_loop() : num =  3571441
# infinite_loop() : num =  3571442
# infinite_loop() : num =  3571443
# infinite_loop() : num =  3571444
# infinite_loop() : num =  3571445
# infinite_loop() : num =  3571446
# infinite_loop() : num =  3571447
# infinite_loop() : num =  3571448
# infinite_loop() : num =  3571449
# infinite_loop() : num =  3571450
# infinite_loop() : num =  3571451
# infinite_loop() : num =  3571452
# infinite_loop() : num =  3571453
# infinite_loop() : num =  3571454
# infinite_loop() : num =  3571455
# infinite_loop() : num =  3571456
# infinite_loop() : num =  3571457
# infinite_loop() : num =  3571458
# infinite_loop() : num =  3571459
# infinite_loop() : num =  3571460
# infinite_loop() : num =  3571461
# infinite_loop() : num =  3571462
# infinite_loop() : num =  3571463
# infinite_loop() : num =  3571464
# infinite_loop() : num =  3571465
# infinite_loop() : num =  3571466
# infinite_loop() : num =  3571467
# infinite_loop() : num =  3571468
# infinite_loop() : num =  3571469
# infinite_loop() : num =  3571470
# infinite_loop() : num =  3571471
# infinite_loop() : num =  3571472
# infinite_loop() : num =  3571473
# infinite_loop() : num =  3571474
# infinite_loop() : num =  3571475
# infinite_loop() : num =  3571476
# infinite_loop() : num =  3571477
# infinite_loop() : num =  3571478
# infinite_loop() : num =  3571479
# infinite_loop() : num =  3571480
# infinite_loop() : num =  3571481
# infinite_loop() : num =  3571482
# infinite_loop() : num =  3571483
# infinite_loop() : num =  3571484
# infinite_loop() : num =  3571485
# infinite_loop() : num =  3571486
# infinite_loop() : num =  3571487
# infinite_loop() : num =  3571488
# infinite_loop() : num =  3571489
# infinite_loop() : num =  3571490
# infinite_loop() : num =  3571491
# infinite_loop() : num =  3571492
# infinite_loop() : num =  3571493
# infinite_loop() : num =  3571494
# infinite_loop() : num =  3571495
# infinite_loop() : num =  3571496
# infinite_loop() : num =  3571497
# infinite_loop() : num =  3571498
# infinite_loop() : num =  3571499
# infinite_loop() : num =  3571500
# infinite_loop() : num =  3571501
# infinite_loop() : num =  3571502
# infinite_loop() : num =  3571503
# infinite_loop() : num =  3571504
# infinite_loop() : num =  3571505
# infinite_loop() : num =  3571506
# infinite_loop() : num =  3571507
# infinite_loop() : num =  3571508
# infinite_loop() : num =
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3100180242.py in <cell line: 0>()
#       6        print("infinite_loop() : num = ", num)
#       7
# ----> 8 infinite_loop()
#
# /tmp/ipython-input-3100180242.py in infinite_loop()
#       4        #yield num   # with yield it become generator without yield its a infinite loop
#       5        num += 1
# ----> 6        print("infinite_loop() : num = ", num)
#       7
#       8 infinite_loop()
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/iostream.py in write(self, string)
#     548         else:
#     549
# --> 550             is_child = not self._is_master_process()
#     551             # only touch the buffer in the IO thread to avoid races
#     552             with self._buffer_lock:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     436
#     437     def _is_master_process(self):
# --> 438         return os.getpid() == self._master_pid
#     439
#     440     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Generator Expressions**
# Generator expressions are a concise way to create generators. They are similar to list comprehensions but use parentheses instead of square brackets.
#
# Example:

# %%
# List comprehension
my_list = [x for x in range(5)]
print(my_list)


# Generator expression
gen = (x for x in range(5))
print(type(gen))

# # Iterate over the generator
for value in gen:
    print(value)

# next(gen)
# Out:
# [0, 1, 2, 3, 4]
# <class 'generator'>
# 0
# 1
# 2
# 3
# 4
